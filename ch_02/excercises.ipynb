# %% [markdown]
# # Exercises
#
# Using the data/parsed.csv file and the material from this chapter, complete the following exercises to practice your pandas skills:
#
# 1. Find the 95th percentile of earthquake magnitude in Japan using the mb magnitude type.
# 2. Find the percentage of earthquakes in Indonesia that were coupled with tsunamis.
# 3. Calculate summary statistics for earthquakes in Nevada.
# 4. Add a column indicating whether the earthquake happened in a country or US state that is on the Ring of Fire. Use Alaska, Antarctica (look for Antarctic), Bolivia, California, Canada, Chile, Costa Rica, Ecuador, Fiji, Guatemala, Indonesia, Japan, Kermadec Islands, Mexico (be careful not to select New Mexico), New Zealand, Peru, Philippines, Russia, Taiwan, Tonga, and Washington.
# 5. Calculate the number of earthquakes in the Ring of Fire locations and the number outside of them.
# 6. Find the tsunami count along the Ring of Fire.

# %%
import pandas as pd
pd.set_option("display.max_columns", None)

df = pd.read_csv("data/parsed.csv")
df["time"] = pd.to_datetime(df["time"])
df.head(5)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  mmi net    nst  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  NaN  ci   26.0
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  NaN  ci   20.0
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  NaN  ci  111.0
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  NaN  ci   26.0
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  NaN  nc   18.0
#
#                    place   rms  sig sources     status  \
# 0  9km NE of Aguanga, CA  0.19   28    ,ci,  automatic
# 1  9km NE of Aguanga, CA  0.29   26    ,ci,  automatic
# 2  8km NE of Aguanga, CA  0.22  192    ,ci,  automatic
# 3  9km NE of Aguanga, CA  0.17    3    ,ci,  automatic
# 4  10km NW of Avenal, CA  0.05   72    ,nc,  automatic
#
#                            time                          title  tsunami  \
# 0 1970-01-01 00:25:39.475168010  M 1.4 - 9km NE of Aguanga, CA        0
# 1 1970-01-01 00:25:39.475129610  M 1.3 - 9km NE of Aguanga, CA        0
# 2 1970-01-01 00:25:39.475062610  M 3.4 - 8km NE of Aguanga, CA        0
# 3 1970-01-01 00:25:39.474978070  M 0.4 - 9km NE of Aguanga, CA        0
# 4 1970-01-01 00:25:39.474716050  M 2.2 - 10km NW of Avenal, CA        0
#
#          type                                              types     tz  \
# 0  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 1  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 2  earthquake  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0
# 3  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 4  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0
#
#          updated                                                url  \
# 0  1539475395144  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1539475253925  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1539536756176  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  1539475196167  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  1539477547926  https://earthquake.usgs.gov/earthquakes/eventp...
#
#   parsed_place
# 0   California
# 1   California
# 2   California
# 3   California
# 4   California

# %%
df.type.unique()
# Out:
# array(['earthquake', 'quarry blast', 'explosion', 'ice quake',
#        'other event'], dtype=object)

# %%
df.tsunami.unique()
# Out:
# array([0, 1])

# %%
df.parsed_place.unique()
# Out:
# array(['California', 'Dominican Republic', 'Alaska', 'Indonesia',
#        'Canada', 'Puerto Rico', 'Montana', 'Nevada', 'Christmas Island',
#        'Hawaii', 'Northern Mariana Islands', 'Japan', 'Ecuador',
#        'Vanuatu', 'Mexico', 'Russia', 'British Virgin Islands',
#        'Washington', 'Papua New Guinea', 'Fiji', 'U.S. Virgin Islands',
#        'Chile', 'Peru', 'Yemen', 'Guatemala', 'Kansas', 'Australia',
#        'Wyoming', 'Kuril Islands', 'Oklahoma', 'Tennessee',
#        'Pacific-Antarctic Ridge', 'Utah', 'Colombia', 'Argentina',
#        'Oregon', 'Greece', 'Missouri', 'Tajikistan',
#        'Northern Mid-Atlantic Ridge', 'Sumatra', 'Solomon Islands',
#        'Burma', 'Taiwan', 'Nicaragua',
#        'South Georgia and South Sandwich Islands', 'Idaho', 'Kyrgyzstan',
#        'Arizona', 'Tonga', 'Northern East Pacific Rise', 'South Africa',
#        'Southern Mid-Atlantic Ridge', 'Costa Rica', 'China',
#        'Philippines', 'Haiti', 'Jamaica', 'Kentucky', 'New Zealand',
#        'Iran', 'Afghanistan', 'Southwest Indian Ridge', 'Saint Helena',
#        'Texas', 'New Caledonia', 'El Salvador',
#        'Central Mid-Atlantic Ridge', 'Western Xizang', 'Italy',
#        'Mid-Indian Ridge', 'Ascension Island', 'North Carolina',
#        'South Sandwich Islands', 'Saint Eustatius and Saba', 'Pakistan',
#        'Bolivia', 'Turkey', 'Indian Ocean Triple Junction', 'Mayotte',
#        'Queen Charlotte Islands', 'India', 'Arkansas', 'Guam',
#        'Uzbekistan', 'Prince Edward Islands', 'Martinique', 'Honduras',
#        'Southern East Pacific Rise', 'East Timor', 'Barbuda', 'Mauritius',
#        'Carlsberg Ridge', 'Greenland', 'Balleny Islands',
#        'Western Indian-Antarctic Ridge', 'South Carolina', 'Vermont',
#        'Romania', 'New Hampshire', 'Central East Pacific Rise',
#        'Southeast Indian Ridge', 'Kermadec Islands', 'Colorado',
#        'Illinois', 'Socotra', 'Azerbaijan', 'Iraq', 'Somalia',
#        'New Mexico'], dtype=object)

# %% [markdown]
# ## 1Q
# Find the 95th percentile of earthquake magnitude in Japan using the mb magnitude type.

# %%
japan = df.query("parsed_place == 'Japan' and magType == 'mb'")
japan.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'parsed_place'],
#       dtype='object')

# %%
print(f'95% percentile is: {japan["mag"].quantile([0.95]).values[0]:.2f}')
# Out:
# 95% percentile is: 4.90

# %% [markdown]
# ## 2Q
# Find the percentage of earthquakes in Indonesia that were coupled with tsunamis.

# %%
indonesia = df.query("parsed_place == 'Indonesia' and type == 'earthquake'")
indonesia.head(3)
# Out:
#      alert  cdi      code                                             detail  \
# 9      NaN  NaN  1000hbtn  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 13     NaN  NaN  1000hbti  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 180  green  NaN  1000hbhw  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt    gap           ids  mag magType   mmi net  nst  \
# 9    3.191   NaN   37.0  ,us1000hbtn,  4.7      mb   NaN  us  NaN
# 13   2.193   NaN  157.0  ,us1000hbti,  4.5      mb   NaN  us  NaN
# 180  2.077   NaN   23.0  ,us1000hbhw,  5.2     mww  3.54  us  NaN
#
#                                   place   rms  sig sources    status  \
# 9       219km SSE of Saparua, Indonesia  0.78  340    ,us,  reviewed
# 13   120km SSW of Banda Aceh, Indonesia  0.69  312    ,us,  reviewed
# 180         25km E of Bitung, Indonesia  1.43  416    ,us,  reviewed
#
#                              time                                       title  \
# 9   1970-01-01 00:25:39.472814760     M 4.7 - 219km SSE of Saparua, Indonesia
# 13  1970-01-01 00:25:39.470898340  M 4.5 - 120km SSW of Banda Aceh, Indonesia
# 180 1970-01-01 00:25:39.405255580         M 5.2 - 25km E of Bitung, Indonesia
#
#      tsunami        type                                            types  \
# 9          0  earthquake                     ,geoserve,origin,phase-data,
# 13         0  earthquake                     ,geoserve,origin,phase-data,
# 180        0  earthquake  ,geoserve,losspager,origin,phase-data,shakemap,
#
#         tz        updated                                                url  \
# 9    540.0  1539473712040  https://earthquake.usgs.gov/earthquakes/eventp...
# 13   360.0  1539493516040  https://earthquake.usgs.gov/earthquakes/eventp...
# 180  480.0  1539412565560  https://earthquake.usgs.gov/earthquakes/eventp...
#
#     parsed_place
# 9      Indonesia
# 13     Indonesia
# 180    Indonesia

# %%
indonesia.tsunami.value_counts(normalize=True)
# Out:
# 0    0.768707
# 1    0.231293
# Name: tsunami, dtype: float64

# %% [markdown]
# ## 3Q
# Calculate summary statistics for earthquakes in Nevada.

# %%
nevada = df.query("parsed_place == 'Nevada'")
nevada.describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  681.000000  15.000000  681.000000  681.000000  1.00
# mean    2.440000    0.166199   2.400000  153.668120    0.500073  2.84
# std     0.501142    0.166228   4.626013   68.735302    0.696710   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.380000   -0.100000  2.84
# 50%     2.200000    0.112000   1.000000  149.140000    0.400000  2.84
# 75%     2.900000    0.233000   1.000000  199.720000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig  tsunami     tz       updated
# count  681.000000  681.000000  681.000000    681.0  681.0  6.810000e+02
# mean    12.618209    0.151986   10.970631      0.0 -480.0  1.538402e+12
# std      9.866963    0.084662   19.607150      0.0    0.0  6.010951e+08
# min      3.000000    0.000500    0.000000      0.0 -480.0  1.537307e+12
# 25%      6.000000    0.106900    0.000000      0.0 -480.0  1.537928e+12
# 50%     10.000000    0.146300    2.000000      0.0 -480.0  1.538428e+12
# 75%     16.000000    0.187100   12.000000      0.0 -480.0  1.538878e+12
# max     61.000000    0.863400  129.000000      0.0 -480.0  1.539483e+12

# %% [markdown]
# ## 4Q
# Add a column indicating whether the earthquake happened in a country or US state that is on the Ring of Fire. Use Alaska, Antarctica (look for Antarctic), Bolivia, California, Canada, Chile, Costa Rica, Ecuador, Fiji, Guatemala, Indonesia, Japan, Kermadec Islands, Mexico (be careful not to select New Mexico), New Zealand, Peru, Philippines, Russia, Taiwan, Tonga, and Washington.

# %%
ring_of_fire = [
    "Alaska", 
    "Antarctic", 
    "Bolivia", 
    "California",
    "Canada", 
    "Chile", 
    "Costa Rica", 
    "Ecuador", 
    "Fiji", 
    "Guatemala", 
    "Indonesia", 
    "Japan", 
    "Kermadec Islands", 
    "Mexico", 
    "New Zealand", 
    "Peru", 
    "Philippines", 
    "Russia", 
    "Taiwan", 
    "Tonga", 
    "Washington"
]

# %%
df = df.assign(ring_of_fire_bool = df["parsed_place"].isin(ring_of_fire))
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  mmi net    nst  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  NaN  ci   26.0
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  NaN  ci   20.0
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  NaN  ci  111.0
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  NaN  ci   26.0
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  NaN  nc   18.0
#
#                    place   rms  sig sources     status  \
# 0  9km NE of Aguanga, CA  0.19   28    ,ci,  automatic
# 1  9km NE of Aguanga, CA  0.29   26    ,ci,  automatic
# 2  8km NE of Aguanga, CA  0.22  192    ,ci,  automatic
# 3  9km NE of Aguanga, CA  0.17    3    ,ci,  automatic
# 4  10km NW of Avenal, CA  0.05   72    ,nc,  automatic
#
#                            time                          title  tsunami  \
# 0 1970-01-01 00:25:39.475168010  M 1.4 - 9km NE of Aguanga, CA        0
# 1 1970-01-01 00:25:39.475129610  M 1.3 - 9km NE of Aguanga, CA        0
# 2 1970-01-01 00:25:39.475062610  M 3.4 - 8km NE of Aguanga, CA        0
# 3 1970-01-01 00:25:39.474978070  M 0.4 - 9km NE of Aguanga, CA        0
# 4 1970-01-01 00:25:39.474716050  M 2.2 - 10km NW of Avenal, CA        0
#
#          type                                              types     tz  \
# 0  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 1  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 2  earthquake  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0
# 3  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 4  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0
#
#          updated                                                url  \
# 0  1539475395144  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1539475253925  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1539536756176  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  1539475196167  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  1539477547926  https://earthquake.usgs.gov/earthquakes/eventp...
#
#   parsed_place  ring_of_fire_bool
# 0   California               True
# 1   California               True
# 2   California               True
# 3   California               True
# 4   California               True

# %%
df['ring_of_fire'] = df.parsed_place.str.contains(r'|'.join([
    'Alaska', 'Antarctic', 'Bolivia', 'California', 'Canada',
    'Chile', 'Costa Rica', 'Ecuador', 'Fiji', 'Guatemala',
    'Indonesia', 'Japan', 'Kermadec Islands', '^Mexico',
    'New Zealand', 'Peru', 'Philippines', 'Russia',
    'Taiwan', 'Tonga', 'Washington' 
]))
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# 9328  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.030410   NaN
# 9329  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.452600   NaN
# 9330  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018650   NaN
# 9331  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.016980   NaN
#
#         gap             ids   mag magType  mmi net    nst  \
# 0      85.0    ,ci37389218,  1.35      ml  NaN  ci   26.0
# 1      79.0    ,ci37389202,  1.29      ml  NaN  ci   20.0
# 2      21.0    ,ci37389194,  3.42      ml  NaN  ci  111.0
# 3      39.0    ,ci37389186,  0.44      ml  NaN  ci   26.0
# 4     192.0    ,nc73096941,  2.16      md  NaN  nc   18.0
# ...     ...             ...   ...     ...  ...  ..    ...
# 9327  185.0    ,nc73086771,  0.62      md  NaN  nc   13.0
# 9328   50.0    ,ci38063967,  1.00      ml  NaN  ci   28.0
# 9329  276.0  ,pr2018261000,  2.40      md  NaN  pr    9.0
# 9330   61.0    ,ci38063959,  1.10      ml  NaN  ci   27.0
# 9331   39.0    ,ci38063935,  0.66      ml  NaN  ci   24.0
#
#                                  place   rms  sig sources     status  \
# 0                9km NE of Aguanga, CA  0.19   28    ,ci,  automatic
# 1                9km NE of Aguanga, CA  0.29   26    ,ci,  automatic
# 2                8km NE of Aguanga, CA  0.22  192    ,ci,  automatic
# 3                9km NE of Aguanga, CA  0.17    3    ,ci,  automatic
# 4                10km NW of Avenal, CA  0.05   72    ,nc,  automatic
# ...                                ...   ...  ...     ...        ...
# 9327      9km ENE of Mammoth Lakes, CA  0.03    6    ,nc,   reviewed
# 9328               3km W of Julian, CA  0.21   15    ,ci,   reviewed
# 9329  35km NNE of Hatillo, Puerto Rico  0.41   89    ,pr,   reviewed
# 9330             9km NE of Aguanga, CA  0.10   19    ,ci,   reviewed
# 9331             9km NE of Aguanga, CA  0.10    7    ,ci,   reviewed
#
#                               time                                     title  \
# 0    1970-01-01 00:25:39.475168010             M 1.4 - 9km NE of Aguanga, CA
# 1    1970-01-01 00:25:39.475129610             M 1.3 - 9km NE of Aguanga, CA
# 2    1970-01-01 00:25:39.475062610             M 3.4 - 8km NE of Aguanga, CA
# 3    1970-01-01 00:25:39.474978070             M 0.4 - 9km NE of Aguanga, CA
# 4    1970-01-01 00:25:39.474716050             M 2.2 - 10km NW of Avenal, CA
# ...                            ...                                       ...
# 9327 1970-01-01 00:25:37.230228060      M 0.6 - 9km ENE of Mammoth Lakes, CA
# 9328 1970-01-01 00:25:37.230135130               M 1.0 - 3km W of Julian, CA
# 9329 1970-01-01 00:25:37.229908180  M 2.4 - 35km NNE of Hatillo, Puerto Rico
# 9330 1970-01-01 00:25:37.229545350             M 1.1 - 9km NE of Aguanga, CA
# 9331 1970-01-01 00:25:37.228864470             M 0.7 - 9km NE of Aguanga, CA
#
#       tsunami        type                                              types  \
# 0           0  earthquake         ,geoserve,nearby-cities,origin,phase-data,
# 1           0  earthquake         ,geoserve,nearby-cities,origin,phase-data,
# 2           0  earthquake  ,dyfi,focal-mechanism,geoserve,nearby-cities,o...
# 3           0  earthquake         ,geoserve,nearby-cities,origin,phase-data,
# 4           0  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit...
# ...       ...         ...                                                ...
# 9327        0  earthquake         ,geoserve,nearby-cities,origin,phase-data,
# 9328        0  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit...
# 9329        0  earthquake                       ,geoserve,origin,phase-data,
# 9330        0  earthquake  ,focal-mechanism,geoserve,nearby-cities,origin...
# 9331        0  earthquake  ,focal-mechanism,geoserve,nearby-cities,origin...
#
#          tz        updated                                                url  \
# 0    -480.0  1539475395144  https://earthquake.usgs.gov/earthquakes/eventp...
# 1    -480.0  1539475253925  https://earthquake.usgs.gov/earthquakes/eventp...
# 2    -480.0  1539536756176  https://earthquake.usgs.gov/earthquakes/eventp...
# 3    -480.0  1539475196167  https://earthquake.usgs.gov/earthquakes/eventp...
# 4    -480.0  1539477547926  https://earthquake.usgs.gov/earthquakes/eventp...
# ...     ...            ...                                                ...
# 9327 -480.0  1537285598315  https://earthquake.usgs.gov/earthquakes/eventp...
# 9328 -480.0  1537276800970  https://earthquake.usgs.gov/earthquakes/eventp...
# 9329 -240.0  1537243777410  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330 -480.0  1537230211640  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331 -480.0  1537305830770  https://earthquake.usgs.gov/earthquakes/eventp...
#
#      parsed_place  ring_of_fire_bool  ring_of_fire
# 0      California               True          True
# 1      California               True          True
# 2      California               True          True
# 3      California               True          True
# 4      California               True          True
# ...           ...                ...           ...
# 9327   California               True          True
# 9328   California               True          True
# 9329  Puerto Rico              False         False
# 9330   California               True          True
# 9331   California               True          True
#
# [9332 rows x 29 columns]

# %% [markdown]
# ## 5Q
# Calculate the number of earthquakes in the Ring of Fire locations and the number outside of them.

# %%
df["ring_of_fire"].value_counts()
# Out:
# True     7188
# False    2144
# Name: ring_of_fire, dtype: int64

# %% [markdown]
# ## 6Q
# 6. Find the tsunami count along the Ring of Fire.

# %%
df[df["ring_of_fire"]].tsunami.sum()
# Out:
# 45
